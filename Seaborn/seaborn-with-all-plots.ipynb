# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/__results__.html
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/__notebook__.ipynb
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/__output__.json
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/custom.css
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/__results___files/__results___5_2.png
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/__results___files/__results___6_1.png
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/__results___files/__results___5_0.png
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/__results___files/__results___5_1.png
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/__results___files/__results___5_4.png
# /kaggle/input/notebooks/eunnoan/notebookb970ac14ec/__results___files/__results___5_3.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results__.html
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__resultx__.html
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__notebook__.ipynb
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__output__.json
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/custom.css
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___15_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___47_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___18_1.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___76_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___39_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___20_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___40_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___85_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___25_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___14_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___31_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___24_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___35_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___36_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___70_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___102_1.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___102_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___46_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___71_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___43_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___16_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___12_1.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___33_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___30_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___37_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___17_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___44_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___29_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___23_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___90_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___41_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___96_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___13_1.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___34_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___32_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___38_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___21_1.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___42_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___26_0.png
# /kaggle/input/notebooks/sanjanabasu/tips-dataset/__results___files/__results___22_1.png

# %% [markdown]
# ## Seaborn Tutorial

# %% [markdown]
# ## Distribution plots
#
# . distplot
# . joinplot
# . pairplot
#
# Practice problem on iris Dataset

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# ## Correlation with Heatmap
#
# A correlation heatmap uses colored cells , typically in a monochromatic scale, to show a 2D correlation matrix (table) between two discrete dimensions or event types. It is very important in feature Selection

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# ## JoinPlot
#
# A join plot allows to study the relationship between 2 numeric variables. The central chart display their correlation . It is usually a sctterplot, a hexbin plot , a 2D histogram or a 2D density plot

# %% [markdown]
# ## Univariate analysis

# %%
sns.jointplot(x='tip',y='total_bill',data=df, kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df, kind='reg')

# %% [markdown]
# ## Pair plot
#
# A "pairs plot" is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value, like this : Pairs plots are just elaborations on this, showing all variables paired with all the other variables

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %% [markdown]
# ## Dist Plot
#
# Distplot helps us to check the distribution of the columns feature

# %%
sns.displot(df['tip'],kde = True)

# %%
sns.displot(df['tip'],kde = False, bins = 10)

# %% [markdown]
# ## Categorical Plots
#
# Seaborn also helps us in doing the analysis on Categorical Data points. In this section we will discuss about
#
# . boxplot
#
# . voilinplot
#
# . counplot

# %%
## Count Plot

sns.countplot(x='day', data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
## Count Plot

sns.countplot(y='sex', data=df)
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
## Bar plot

sns.barplot(y='total_bill',x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
## Bar plot

sns.barplot(x='sex',y='total_bill',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Box plot
#
# A box and whisker plot(sometimes called a boxplot) is a graph that presents information from five-number summary

# %%
sns.boxplot(x='sex', y='total_bill', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y= "total_bill",data=df,palette='rainbow')
# Out:
# /tmp/ipykernel_16/1507106909.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day",y= "total_bill",data=df,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df,orient='v')
# Out:
# <Axes: >

# %%
# categorize my data based on some other categories

sns.boxplot(x="total_bill", y = "day", hue= "smoker", data= df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## Violin Plot
#
# Violin plot helps us to see both the distribution of data in terms of kernel density estimation and the box plot

# %%
sns.violinplot(x="total_bill", y = "day", data= df, palette = 'rainbow')
# Out:
# /tmp/ipykernel_16/2749868485.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="total_bill", y = "day", data= df, palette = 'rainbow')
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
## Practice Homewrok 

iris = sns.load_dataset('iris')
