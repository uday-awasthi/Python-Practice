# %% [markdown]
# ## Python Data Structures and Boolean

# %% [markdown]
# . Boolean
#
# . Boolean and Logical Operators
#
# . Lists
#
# . Comparison operators
#
# . Dictionaries
#
# . Tuples
#
# . Sets

# %% [markdown]
# ### Boolean Variables
#
# Boolean values are the the two constant objects False and True.
#
# They are used to represt truth values (other values can also be considered false or true).
#
# In numeric contexts (for example, when used as the argument to an arithmetic operator), they behave like the integers 0 and 1, respectively.
#
# The built-in function bool() can be used to cast any value to a Boolean, if the value can be interpreted as a truth value.
#
# They are written as False and True, respectively

# %%
False
# Out:
# False

# %%
print(True,False)
# Out:
# True False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
my_str='Uday123'

# %%
my_str.isalnum()
# Out:
# True

# %%
print(my_str.isalnum())      # check if all char are numbers
print(my_str.isalpha())      # check if all char in the string are alphabetic
print(my_str.isdigit())      # test if string contains digits
print(my_str.istitle())      # test if string contains title words
print(my_str.isupper())      # test if string contains upper case
print(my_str.islower())      # test if string contains lower case
print(my_str.isspace())      # test if string contains spaces
print(my_str.endswith('i'))  # test if string endswith a d
print(my_str.startswith('U'))# test if string startswith H
# Out:
# True
# False
# False
# True
# False
# False
# False
# False
# True

# %% [markdown]
# ## Boolean and Logical Operators

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
str_example='Hello World'
my_str='Krish'

# %%
my_str.isalpha() or str_example.isnum()
# Out:
# True

# %% [markdown]
# ### Lists
#
#
# A list in Python is an ordered and mutable (changeable) collection of elements.
#
# It can store multiple values of different data types in a single variable.
#
# Lists are created using square brackets [ ] and elements can be added, removed, or modified after creation.

# %%
type([])
# Out:
# list

# %%
lst_example=[]

# %%
type(lst_example)
# Out:
# list

# %%
lst=list()

# %%
type(lst)
# Out:
# list

# %%
lst=['Mathematics', 'chamistry', 100, 200, 300, 204]

# %%
len(lst)
# Out:
# 6

# %%
type(lst)
# Out:
# list

# %% [markdown]
# ### Append

# %%
#. append is used to add elements in the list
lst.append("Uday")

# %%
lst.append(["John","Bala"])

# %%
lst
# Out:
# ['Mathematics', 'chamistry', 100, 200, 300, 204, 'Uday', ['John', 'Bala']]

# %%
## Indexing in list
lst[2]
# Out:
# 100

# %%
lst[1:6]
# Out:
# ['chamistry', 100, 200, 300, 204]

# %% [markdown]
# ### Insert

# %%
## insert in a specific orderr
lst.insert(2,"Awasthi")

# %%
lst
# Out:
# ['Mathematics',
#  'chamistry',
#  'Awasthi',
#  100,
#  200,
#  300,
#  204,
#  'Uday',
#  ['John', 'Bala']]

# %%
lst.append(["Hello","World"])

# %%
lst
# Out:
# ['Mathematics',
#  'chamistry',
#  'Awasthi',
#  100,
#  200,
#  300,
#  204,
#  'Uday',
#  ['John', 'Bala'],
#  ['Hello', 'World']]

# %% [markdown]
# ## Extend Method

# %%
lst = [1,2,3,4,5,6]

# %%
lst.extend([8,9])

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9]

# %% [markdown]
# ### Various Operations that we can perform in List

# %%
lst=[1,2,3,4,5]

# %%
sum(lst)
# Out:
# 16

# %%
## when we do this list will be appended 5 times
lst*5
# Out:
# [1,
#  1,
#  2,
#  3,
#  4,
#  5,
#  1,
#  1,
#  2,
#  3,
#  4,
#  5,
#  1,
#  1,
#  2,
#  3,
#  4,
#  5,
#  1,
#  1,
#  2,
#  3,
#  4,
#  5,
#  1,
#  1,
#  2,
#  3,
#  4,
#  5]

# %% [markdown]
#  ### Pop() Method

# %%
lst.pop()
# Out:
# 5

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
lst.pop(0)
# Out:
# 1

# %%
lst
# Out:
# [2, 3, 4]

# %% [markdown]
# ### count():Calculates total occurance of given element of List

# %%
lst=[1,1,2,3,4,5]
lst.count(1)
# Out:
# 2

# %%
#Length : Calculates total length of List
len(lst)
# Out:
# 6

# %%
#index(): Return the index of first occurance. Start and End index are not neccessary parameters
lst.index(1,1,4)
# Out:
# 1

# %%
## Min and Max
min(lst)
# Out:
# 1

# %%
max(lst)
# Out:
# 5
