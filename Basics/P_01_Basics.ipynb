# %%
##  how to make a heading 
## select markdown cell 
##  then write the content and add ## in the starting

# %% [markdown]
# ## This is Heading

# %%
print("Hello World")
# Out:
# Hello World

# %%
x = 3

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# x          int     3

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x = 9.5

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# x          float    9.5

# %%
print(type(x))
# Out:
# <class 'float'>
